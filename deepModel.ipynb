# %%
import Model
# Out:
# Tick data provided by nyxdata
# AAPL_20180117.gz
# ./data/AAPL_20180117.gz

# %%
agent =  Model.ExecutionAgent()

# %%
agent.train()
# Out:
# INFO:tensorflow:Restoring parameters from ./model/parameters.ckpt
# Model saved in path ./model/parameters.ckpt

# %%
agent.execute_minute()
# Out:
# INFO:tensorflow:Restoring parameters from ./model/parameters.ckpt
# Model Restored
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# ~/miniconda3/envs/dlenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/miniconda3/envs/dlenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/miniconda3/envs/dlenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
# ...
